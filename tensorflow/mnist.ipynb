# %% [markdown]
# # 手書き文字の認識
# ## mnist

# %%
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf

# データの読み込み
mnist = input_data.read_data_sets('.data/', one_hot=True)

# 訓練データの取得
train_images, train_labels = mnist.train.next_batch(50) # ミニバッチ数を指定して取得

# テスト用の画像データを取得
test_images = mnist.test.images

# テスト用のラベルデータ(正解)を取得
test_labels = mnist.test.labels
# Out:
# Extracting .data/train-images-idx3-ubyte.gz
# Extracting .data/train-labels-idx1-ubyte.gz
# Extracting .data/t10k-images-idx3-ubyte.gz
# Extracting .data/t10k-labels-idx1-ubyte.gz

# %%
# 入力データを定義
x = tf.placeholder(tf.float32, [None, 784])

# 入力層から中間層の定義
w_1 = tf.Variable(tf.truncated_normal([784, 64], stddev=0.1), name='w1') # 切断正規分布(標準偏差=0.1)から乱数を生成
b_1 = tf.Variable(tf.zeros([64]), name='b1') # 重みは 0 で初期化
h_1 = tf.nn.relu(tf.matmul(x, w_1) + b_1) # 活性化関数として Relu　関数を利用

# 中間層から出力層の定義
w_2 = tf.Variable(tf.truncated_normal([64, 10], stddev=0.1), name='w_2')
b_2 = tf.Variable(tf.zeros([10]), name='b2')
out = tf.nn.softmax(tf.matmul(h_1, w_2) + b_2) # 出力層は確率を出力するため Softmax 関数を利用

# 誤差関数の定義
y = tf.placeholder(tf.float32, [None, 10]) # プレースホルダーを利用
loss = tf.reduce_mean(tf.square(y - out)) # 全二乗誤差の平均

# 訓練
train_step = tf.train.GradientDescentOptimizer(0.5).minimize(loss) # 確率的勾配降下法(学習率=0.5)

# 評価
correct = tf.equal(tf.argmax(out, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# 実行
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    test_images = mnist.test.images
    test_labels = mnist.test.labels
    
    for i in range(1000):
        step = i + 1
        train_images, train_labels = mnist.train.next_batch(50) # ミニバッチを取得
        sess.run(train_step, feed_dict={x:train_images, y:train_labels}) # 訓練を実行
        
        if step % 10 == 0:
            acc_val = sess.run(accuracy, feed_dict={x:test_images, y:test_labels}) # 精度計算を実行
            print('Step %d: accuracy = %.2f' % (step, acc_val))
# Out:
# Step 10: accuracy = 0.10
# Step 20: accuracy = 0.15
# Step 30: accuracy = 0.21
# Step 40: accuracy = 0.24
# Step 50: accuracy = 0.27
# Step 60: accuracy = 0.32
# Step 70: accuracy = 0.40
# Step 80: accuracy = 0.45
# Step 90: accuracy = 0.49
# Step 100: accuracy = 0.51
# Step 110: accuracy = 0.53
# Step 120: accuracy = 0.56
# Step 130: accuracy = 0.57
# Step 140: accuracy = 0.58
# Step 150: accuracy = 0.59
# Step 160: accuracy = 0.62
# Step 170: accuracy = 0.65
# Step 180: accuracy = 0.68
# Step 190: accuracy = 0.69
# Step 200: accuracy = 0.69
# Step 210: accuracy = 0.71
# Step 220: accuracy = 0.72
# Step 230: accuracy = 0.74
# Step 240: accuracy = 0.74
# Step 250: accuracy = 0.75
# Step 260: accuracy = 0.75
# Step 270: accuracy = 0.78
# Step 280: accuracy = 0.78
# Step 290: accuracy = 0.79
# Step 300: accuracy = 0.79
# Step 310: accuracy = 0.80
# Step 320: accuracy = 0.80
# Step 330: accuracy = 0.81
# Step 340: accuracy = 0.81
# Step 350: accuracy = 0.82
# Step 360: accuracy = 0.82
# Step 370: accuracy = 0.83
# Step 380: accuracy = 0.82
# Step 390: accuracy = 0.83
# Step 400: accuracy = 0.84
# Step 410: accuracy = 0.84
# Step 420: accuracy = 0.84
# Step 430: accuracy = 0.84
# Step 440: accuracy = 0.85
# Step 450: accuracy = 0.85
# Step 460: accuracy = 0.85
# Step 470: accuracy = 0.85
# Step 480: accuracy = 0.86
# Step 490: accuracy = 0.86
# Step 500: accuracy = 0.86
# Step 510: accuracy = 0.86
# Step 520: accuracy = 0.86
# Step 530: accuracy = 0.86
# Step 540: accuracy = 0.87
# Step 550: accuracy = 0.86
# Step 560: accuracy = 0.87
# Step 570: accuracy = 0.87
# Step 580: accuracy = 0.87
# Step 590: accuracy = 0.87
# Step 600: accuracy = 0.87
# Step 610: accuracy = 0.88
# Step 620: accuracy = 0.88
# Step 630: accuracy = 0.88
# Step 640: accuracy = 0.88
# Step 650: accuracy = 0.88
# Step 660: accuracy = 0.88
# Step 670: accuracy = 0.88
# Step 680: accuracy = 0.88
# Step 690: accuracy = 0.88
# Step 700: accuracy = 0.88
# Step 710: accuracy = 0.88
# Step 720: accuracy = 0.88
# Step 730: accuracy = 0.88
# Step 740: accuracy = 0.88
# Step 750: accuracy = 0.88
# Step 760: accuracy = 0.89
# Step 770: accuracy = 0.89
# Step 780: accuracy = 0.89
# Step 790: accuracy = 0.89
# Step 800: accuracy = 0.89
# Step 810: accuracy = 0.89
# Step 820: accuracy = 0.89
# Step 830: accuracy = 0.89
# Step 840: accuracy = 0.89
# Step 850: accuracy = 0.89
# Step 860: accuracy = 0.89
# Step 870: accuracy = 0.89
# Step 880: accuracy = 0.89
# Step 890: accuracy = 0.89
# Step 900: accuracy = 0.89
# Step 910: accuracy = 0.89
# Step 920: accuracy = 0.89
# Step 930: accuracy = 0.90
# Step 940: accuracy = 0.89
# Step 950: accuracy = 0.90
# Step 960: accuracy = 0.89
# Step 970: accuracy = 0.90
# Step 980: accuracy = 0.90
# Step 990: accuracy = 0.90
# Step 1000: accuracy = 0.90
