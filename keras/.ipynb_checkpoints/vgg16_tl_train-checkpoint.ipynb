# %%
import os
import plaidml.keras
plaidml.keras.install_backend() # PlaidML の利用

from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.models import Sequential, Model
from keras.layers import Input, Activation, Flatten, Dense, Dropout
from keras import optimizers
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.display import Image, display

# %%
# クラスの設定
classes = ['apple', 'banana', 'cherry', 'grape', 'melon', 'orange', 'strawberry']
nb_classes = len(classes)

# 画像データのサイズ
img_rows = 100
img_cols = 100
channels = 3

# 学習パラメーター
batch_size = 32
epochs = 50

# データ保管場所
train_data_dir = './data/train'
validation_data_dir = './data/validation'

# 結果保存先
result_dir = './results'
if not os.path.exists(result_dir): # 存在しなければ作成
    os.mkdir(result_dir)

# %%
# ベースモデルの準備(VGG16)
input_tensor = Input(shape=(img_rows, img_cols, 3))
base_model = VGG16(include_top=False, weights='imagenet', input_tensor=input_tensor)
base_model.summary()
# Out:
# INFO:plaidml:Opening device "metal_amd_radeon_rx_vega_56.0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100, 100, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 100, 100, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 100, 100, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 50, 50, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 50, 50, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 50, 50, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 25, 25, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 25, 25, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 12, 12, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 12, 12, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 出力層の作成
x = base_model.output
x = Flatten(input_shape=base_model.output_shape[1:])(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(nb_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100, 100, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 100, 100, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 100, 100, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 50, 50, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 50, 50, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 50, 50, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 25, 25, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 25, 25, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 12, 12, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 12, 12, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 1799
# =================================================================
# Total params: 15,896,391
# Trainable params: 15,896,391
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 再学習しない層を指定(最後のconv層の前までは再学習しない)
for layer in model.layers[:15]:
    layer.trainable = False

# %%
# モデルのコンパイル
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
              metrics=['accuracy'])

# %%
# データジェネレーターを定義
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255,
    shear_range=0.2,# シアー変換
    zoom_range=0.2, #  ランダムに　ズーム
    rotation_range=5, # ランダムに回転する角度
    horizontal_flip=True # 水平方向に反転
)

test_datagen = ImageDataGenerator(rescale=1.0 / 255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_rows, img_cols),
    color_mode='rgb',
    classes=classes,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=True)

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_rows, img_cols),
    color_mode='rgb',
    classes=classes,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=True)
# Out:
# Found 4565 images belonging to 7 classes.
# Found 697 images belonging to 7 classes.

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=train_generator.samples//batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples//batch_size
)
# Out:
# Epoch 1/50
# INFO:plaidml:Analyzing Ops: 91 of 291 operations complete
# 121/142 [========================>.....] - ETA: 6s - loss: 1.6473 - acc: 0.4114
# INFO:plaidml:Analyzing Ops: 88 of 292 operations complete
# INFO:plaidml:Analyzing Ops: 229 of 292 operations complete
# 141/142 [============================>.] - ETA: 0s - loss: 1.6009 - acc: 0.4282
# INFO:plaidml:Analyzing Ops: 94 of 192 operations complete
# 142/142 [==============================] - 56s 392ms/step - loss: 1.5994 - acc: 0.4290 - val_loss: 1.5489 - val_acc: 0.4613
# Epoch 2/50
# 141/142 [============================>.] - ETA: 0s - loss: 1.2434 - acc: 0.5761
# INFO:plaidml:Analyzing Ops: 122 of 193 operations complete
# 142/142 [==============================] - 50s 353ms/step - loss: 1.2432 - acc: 0.5764 - val_loss: 1.2611 - val_acc: 0.5323
# Epoch 3/50
# 142/142 [==============================] - 48s 335ms/step - loss: 1.0446 - acc: 0.6562 - val_loss: 1.1163 - val_acc: 0.5985
# Epoch 4/50
# 142/142 [==============================] - 47s 331ms/step - loss: 0.9402 - acc: 0.6940 - val_loss: 1.0373 - val_acc: 0.6120
# Epoch 5/50
# 142/142 [==============================] - 47s 328ms/step - loss: 0.8564 - acc: 0.7203 - val_loss: 0.9986 - val_acc: 0.6301
# Epoch 6/50
# 142/142 [==============================] - 46s 325ms/step - loss: 0.7874 - acc: 0.7400 - val_loss: 0.9001 - val_acc: 0.6556
# Epoch 7/50
# 142/142 [==============================] - 46s 322ms/step - loss: 0.7291 - acc: 0.7547 - val_loss: 0.9346 - val_acc: 0.6436
# Epoch 8/50
# 142/142 [==============================] - 46s 324ms/step - loss: 0.6814 - acc: 0.7759 - val_loss: 0.8886 - val_acc: 0.6707
# Epoch 9/50
# 142/142 [==============================] - 45s 316ms/step - loss: 0.6277 - acc: 0.7901 - val_loss: 0.8560 - val_acc: 0.6707
# Epoch 10/50
# 142/142 [==============================] - 45s 315ms/step - loss: 0.5945 - acc: 0.8019 - val_loss: 0.7453 - val_acc: 0.6932
# Epoch 11/50
# 142/142 [==============================] - 44s 310ms/step - loss: 0.5697 - acc: 0.8064 - val_loss: 0.8272 - val_acc: 0.6977
# Epoch 12/50
# 142/142 [==============================] - 44s 310ms/step - loss: 0.5330 - acc: 0.8223 - val_loss: 0.6874 - val_acc: 0.7008
# Epoch 13/50
# 142/142 [==============================] - 43s 304ms/step - loss: 0.5189 - acc: 0.8279 - val_loss: 0.7374 - val_acc: 0.7323
# Epoch 14/50
# 142/142 [==============================] - 43s 302ms/step - loss: 0.4870 - acc: 0.8327 - val_loss: 0.7246 - val_acc: 0.7353
# Epoch 15/50
# 142/142 [==============================] - 43s 300ms/step - loss: 0.4668 - acc: 0.8431 - val_loss: 0.6212 - val_acc: 0.7594
# Epoch 16/50
# 142/142 [==============================] - 43s 301ms/step - loss: 0.4574 - acc: 0.8416 - val_loss: 0.7197 - val_acc: 0.7293
# 142/142 [==============================] - 43s 300ms/step - loss: 0.2260 - acc: 0.9259 - val_loss: 0.7274 - val_acc: 0.7639
# Epoch 39/50
# 142/142 [==============================] - 43s 302ms/step - loss: 0.2313 - acc: 0.9203 - val_loss: 0.6214 - val_acc: 0.7925
# Epoch 40/50
# 142/142 [==============================] - 43s 301ms/step - loss: 0.2019 - acc: 0.9323 - val_loss: 0.7490 - val_acc: 0.7850
# Epoch 41/50
# 142/142 [==============================] - 43s 301ms/step - loss: 0.2063 - acc: 0.9269 - val_loss: 0.5775 - val_acc: 0.7940
# Epoch 42/50
# 142/142 [==============================] - 43s 302ms/step - loss: 0.2100 - acc: 0.9327 - val_loss: 0.6977 - val_acc: 0.7609
# Epoch 43/50
# 142/142 [==============================] - 43s 303ms/step - loss: 0.1947 - acc: 0.9320 - val_loss: 0.6622 - val_acc: 0.7805
# Epoch 44/50
# 142/142 [==============================] - 43s 302ms/step - loss: 0.2020 - acc: 0.9276 - val_loss: 0.5726 - val_acc: 0.8045
# Epoch 45/50
# 142/142 [==============================] - 43s 301ms/step - loss: 0.1913 - acc: 0.9335 - val_loss: 0.6189 - val_acc: 0.8006
# Epoch 46/50
# 142/142 [==============================] - 46s 321ms/step - loss: 0.1702 - acc: 0.9443 - val_loss: 0.6254 - val_acc: 0.7805
# Epoch 47/50
# 142/142 [==============================] - 45s 316ms/step - loss: 0.1783 - acc: 0.9390 - val_loss: 0.6468 - val_acc: 0.8000
# Epoch 48/50
# 142/142 [==============================] - 45s 315ms/step - loss: 0.1793 - acc: 0.9357 - val_loss: 0.7988 - val_acc: 0.7699
# Epoch 49/50
# 142/142 [==============================] - 44s 313ms/step - loss: 0.1698 - acc: 0.9438 - val_loss: 0.7072 - val_acc: 0.8060
# Epoch 50/50
# 142/142 [==============================] - 44s 312ms/step - loss: 0.1688 - acc: 0.9450 - val_loss: 0.7510 - val_acc: 0.7669

# %%
history.history
# Out:
# {'val_loss': [1.5489350046430315,
#   1.2610813047652853,
#   1.1162606133554214,
#   1.0372534420257224,
#   0.998607433648934,
#   0.9001484456815217,
#   0.9345803947377026,
#   0.8885596586349315,
#   0.8559793448089656,
#   0.7452939616110091,
#   0.8271896236821225,
#   0.6873818818787883,
#   0.7373518630974275,
#   0.7245685849870954,
#   0.6211870008841494,
#   0.7196668192856294,
#   0.7495797512226535,
#   0.6408993340972671,
#   0.7609227302379178,
#   0.7415585451556328,
#   0.8720191220591839,
#   0.6319567318249466,
#   0.711510629880996,
#   0.6763557846384837,
#   0.6794608482740876,
#   0.6958420256923016,
#   0.6459165319464261,
#   0.6555628683334006,
#   0.6988336951212776,
#   0.719142910860535,
#   0.6793447524085081,
#   0.7104739741275184,
#   0.7116881701282989,
#   0.6318190824716611,
#   0.6755198768431083,
#   0.657371929803289,
#   0.6189917273987505,
#   0.7273881337696448,
#   0.6213923403643128,
#   0.7490102459613542,
#   0.5774927393834394,
#   0.6977450062457781,
#   0.6621968274726007,
#   0.5726000521416055,
#   0.618881222747621,
#   0.6253504101495098,
#   0.646801325521971,
#   0.7987598842247985,
#   0.7071655777163972,
#   0.7510472176666546],
#  'val_acc': [0.46130952380952384,
#   0.532330826529883,
#   0.5984962398844554,
#   0.9259177355548018,
#   0.9203617913344825,
#   0.9322744319566743,
#   0.9272005295032911,
#   0.9324950363997353,
#   0.9318332230311053,
#   0.9275968309859155,
#   0.933436532534102,
#   0.9443221830985915,
#   0.9387439186200797,
#   0.9355834987866755,
#   0.9439664681621033,
#   0.9450694904300042]}

# %%
# plot results
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(range(epochs), loss, marker='.', label='loss')
plt.plot(range(epochs), val_loss, marker='.', label='val_loss')
plt.legend(loc='best')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# plot results
acc = history.history['acc']
val_acc = history.history['val_acc']

plt.plot(range(epochs), acc, marker='.', label='acc')
plt.plot(range(epochs), val_acc, marker='.', label='val_acc')
plt.legend(loc='best')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.show()

# %%
import pickle

# %%
with open('./results/history1.pkl', mode='wb') as f:
    pickle.dump(history.history, f)

# %%
model.save('./results/vgg16-finetuning.h5')

# %%
def predict(img_file_path):
    
    display(Image(img_file_path, width=150, unconfined=True))
    img = image.load_img(img_file_path, target_size=(img_rows, img_cols))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)

    # 学習時にImageDataGeneratorのrescaleで正規化したので同じ処理が必要！
    # これを忘れると結果がおかしくなるので注意
    x = x / 255.0

    # クラスを予測
    # 入力は1枚の画像なので[0]のみ
    pred = model.predict(x)[0]

    # 予測確率が高いトップ5を出力
    top = 5
    top_indices = pred.argsort()[-top:][::-1]
    result = [(classes[i], pred[i]) for i in top_indices]
    for x in result:
        print(x)

# %%
predict('./data/samples/strawberry1.jpg')
# Out:
# INFO:plaidml:Analyzing Ops: 101 of 160 operations complete
# ('strawberry', 0.9999821)
# ('melon', 1.7520237e-05)
# ('apple', 1.2054507e-07)
# ('grape', 1.1921016e-07)
# ('cherry', 7.094587e-08)

# %%
predict('./data/samples/banana1.jpg')
# Out:
# ('banana', 0.99998915)
# ('orange', 4.2680144e-06)
# ('melon', 3.614801e-06)
# ('apple', 2.9804637e-06)
# ('grape', 5.147278e-08)

# %%
predict('./data/samples/cherry1.jpg')
# Out:
# ('strawberry', 0.7507917)
# ('cherry', 0.24595512)
# ('grape', 0.0026845702)
# ('orange', 0.00036556012)
# ('melon', 0.00011972542)

# %%
predict('./data/samples/melon1.jpg')
# Out:
# ('melon', 0.90375656)
# ('apple', 0.044598103)
# ('banana', 0.040673815)
# ('orange', 0.009012733)
# ('strawberry', 0.0016184513)

# %%
predict('./data/samples/apple1.jpg')
# Out:
# ('apple', 0.9999747)
# ('orange', 2.4752617e-05)
# ('cherry', 2.934592e-07)
# ('strawberry', 6.97689e-08)
# ('melon', 6.9740494e-08)

# %%
predict('./data/samples/strawberry2.jpg')
# Out:
# ('strawberry', 0.9999988)
# ('orange', 1.002823e-06)
# ('melon', 7.941456e-08)
# ('cherry', 7.588032e-08)
# ('banana', 6.8806916e-09)

# %%
predict('./data/samples/grape1.jpg')
# Out:
# ('grape', 0.9930474)
# ('strawberry', 0.0062089264)
# ('cherry', 0.00034872635)
# ('melon', 0.00030022222)
# ('banana', 5.9954695e-05)
